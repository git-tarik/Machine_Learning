# %%
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np

import plotly.express as px
import plotly.graph_objects as go

from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
X,y = make_regression(n_samples=100, n_features=2, n_informative=2, n_targets=1, noise=50)

# %%
df = pd.DataFrame({'feature1':X[:,0],'feature2':X[:,1],'target':y})

# %%
df.shape
# Out:
# (100, 3)

# %%
df.head()
# Out:
#    feature1  feature2      target
# 0  1.143889 -1.006313   97.152777
# 1 -2.375082  1.522124 -126.769729
# 2 -0.718452  0.143480    1.598912
# 3  0.857839  0.414089   36.354396
# 4  0.336336 -0.818139   33.432738

# %%
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
print("R2 score",r2_score(y_test,y_pred))
# Out:
# MAE 38.540986630005506
# MSE 2175.835299959164
# R2 score 0.5902954008380972

# %%
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)
xGrid, yGrid = np.meshgrid(y, x)

z_final = lr.predict(final).reshape(10,10)

z = z_final

final = np.vstack((xGrid.ravel().reshape(1,100),yGrid.ravel().reshape(1,100))).T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2741823406.py in <cell line: 0>()
#       3 xGrid, yGrid = np.meshgrid(y, x)
#       4
# ----> 5 z_final = lr.predict(final).reshape(10,10)
#       6
#       7 z = z_final
#
# NameError: name 'final' is not defined

# %%
import numpy as np
# Assuming 'lr' is a defined and trained model object
# ...

# 1. Define the grid points
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)
xGrid, yGrid = np.meshgrid(y, x) # Note: Be mindful of which array is passed first

# 2. Create the input array 'final' for prediction
#    This prepares the 100 points as a (100, 2) array (one point per row)
final = np.vstack((xGrid.ravel(), yGrid.ravel())).T
# Note: Simplified the reshape calls in vstack since .ravel() already produces a (100,) array
# which vstack will promote to (1, 100) automatically before transpose.

# 3. Use 'final' to make predictions
z_final = lr.predict(final).reshape(10,10)

# 4. Assign to z (optional)
z = z_final

# %%
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)
xGrid, yGrid = np.meshgrid(y, x)

z_final = lr.predict(final).reshape(10,10)

z = z_final

final = np.vstack((xGrid.ravel().reshape(1,100),yGrid.ravel().reshape(1,100))).T

# %%
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

fig.add_trace(go.Surface(x = x, y = y, z =z ))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
lr.coef_
# Out:
# array([64.03350373,  6.18868184])

# %%
lr.intercept_
# Out:
# np.float64(-3.063429048550594)
